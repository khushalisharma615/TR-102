# %%
1. Challeges on data extraction- Various email formats, 
high vol of data,
 consisitnecy in extracted data,
  navigating spam ansd irrelevant content,
  integration issues.

2.Backing up email data of specific email id on outlook with incoming and outgoing maails thorugh IMAP/ SMTP respectably.

c:\Users\PC\OneDrive\Pictures\Screenshots\Screenshot (294).png

3.How to covert PDF or other attachemtns like Image yo text?
- Via OCR 
OCR stands for Optical Character Recognition. It is a technology that converts text in an image into a machine-readable format. 
 
OCR is used to convert physical documents or images into electronic versions with text. For example, if you scan a receipt, your computer will save it as an image file. However, you can use OCR to convert the image into a text document that you can edit, search, or count the words in. 
  
4.html.2pdf package- jvascript library to covert HTML to canvas, PDF, images.

5. CSV(comma separated values)file: Opted for spread sheet like excel .

# %% [markdown]
# ![Screenshot (294).png](<attachment:Screenshot (294).png>)
